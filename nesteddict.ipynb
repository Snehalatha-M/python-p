# %%
# Write a program to create a nested dictionary representing 3 students,
# with each student having a name and a dictionary of subjects with grades
# Prompt the user for a student name and subject, then print the corresponding grade or an error message if not found.


std_1={ 

   "Sneha" : 
{

 'marks' : {
    

     
      "Maths" : 98,
      "Telugu" : 95,
      "English" : 92,
      "Hindi" : 95,
      "Science" : 96,
      "Social" : 98
}
}
}

# %%
std_1
# Out:
# {'Sneha': {'marks': {'Maths': 98,
#    'Telugu': 95,
#    'English': 92,
#    'Hindi': 95,
#    'Science': 96,
#    'Social': 98}}}

# %%
std_1={ 

   "Sneha" : 
{

'Marks': {
     
      "Maths" : 98,
      "Telugu" : 95,
      "English" : 92,
      "Hindi" : 95,
      "Science" : 96,
      "Social" : 98
},

'Grade' : {
 
    'grade': "PASS"
},

'Address' : {

     'Address' : "Hyderabad"
}, 

'Contact_info' : {

    'Phone Number' : 9874561230,
    'Mail-id' : " msl@gmail.com"
}

}
}

# %%
std_1
# Out:
# {'Sneha': {'Marks': {'Maths': 98,
#    'Telugu': 95,
#    'English': 92,
#    'Hindi': 95,
#    'Science': 96,
#    'Social': 98},
#   'Grade': {'grade': 'PASS'},
#   'Address': {'Address': 'Hyderabad'},
#   'Contact_info': {'Phone Number': 9874561230, 'Mail-id': ' msl@gmail.com'}}}

# %%
std_1={ 

   "Sneha" : 
{

'Marks': {
     
      "Maths" : 98,
      "Telugu" : 95,
      "English" : 92,
      "Hindi" : 95,
      "Science" : 96,
      "Social" : 98
},

'Grade' : {
 
    'grade': "PASS"
},

'Address' : {

     'Address' : "Hyderabad"
}, 

'Contact_info' : {

    'Phone Number' : 9874561230,
    'Mail-id' : " msl@gmail.com"
}
}
}
std_2={ 

   "Ravalika" : 
{

'Marks': {
     
      "Maths" : 98,
      "Telugu" : 92,
      "English" : 92,
      "Hindi" : 95,
      "Science" : 97,
      "Social" : 96
},

'Grade' : {
 
    'grade': "PASS"
},

'Address' : {

     'Address' : "Hyderabad"
}, 

'Contact' :{

    'Phone Number' : 7894561230,
    'Mail-id' : " prr@gmail.com"
}
}
}
import pprint

pprint.pp(std_1)
pprint.pp(std_2)
# Out:
# {'Sneha': {'Marks': {'Maths': 98,
#                      'Telugu': 95,
#                      'English': 92,
#                      'Hindi': 95,
#                      'Science': 96,
#                      'Social': 98},
#            'Grade': {'grade': 'PASS'},
#            'Address': {'Address': 'Hyderabad'},
#            'Contact_info': {'Phone Number': 9874561230,
#                             'Mail-id': ' msl@gmail.com'}}}
# {'Ravalika': {'Marks': {'Maths': 98,
#                         'Telugu': 92,
#                         'English': 92,
#                         'Hindi': 95,
#                         'Science': 97,
#                         'Social': 96},
#               'Grade': {'grade': 'PASS'},
#               'Address': {'Address': 'Hyderabad'},
#               'Contact': {'Phone Number': 7894561230,
#                           'Mail-id': ' prr@gmail.com'}}}

# %%
std_1={ 

   "Sneha" : 
{

'Marks': { "Maths" : 98, "Telugu" : 95, "English" : 92, "Hindi" : 95, "Science" : 96, "Social" :98 },

'Grade' :  "PASS" ,
 

'Address' : "Hyderabad" ,
    
'Contact_info' : {'Phone Number' : 9874561230, 'Mail-id' : " msl@gmail.com"}
}
}
import pprint

pprint.pp(std_1)
# Out:
# {'Sneha': {'Marks': {'Maths': 98,
#                      'Telugu': 95,
#                      'English': 92,
#                      'Hindi': 95,
#                      'Science': 96,
#                      'Social': 98},
#            'Grade': 'PASS',
#            'Address': 'Hyderabad',
#            'Contact_info': {'Phone Number': 9874561230,
#                             'Mail-id': ' msl@gmail.com'}}}

# %%
std_1={ 

   "Sneha" : 
{

'Marks': { "Maths" : 98, "Telugu" : 95, "English" : 92, "Hindi" : 95, "Science" : 96, "Social" :98 },

'Grade' :  "PASS" ,
 

'Address' : "Hyderabad" ,
    
'Contact_info' :{ 'Phone Number' : 9874561230, 'Mail-id' : " msl@gmail.com"}
}
}
std_2={

    "Ravalika":
{

'Marks': { "Maths" : 96, "Telugu" : 94, "English" : 91, "Hindi" : 90, "Science" : 90, "Social" :94 },

'Grade' :  "PASS" ,

'Address' : "Hyderabad" ,

'Contact_info' : { 'Phone Number' : 7894561230, 'Mail-id' : " prr@gmail.com" }

}
}


std_3={

    "Archana":
{

'Marks': { "Maths" : 98, "Telugu" : 98, "English" : 96, "Hindi" : 95, "Science" : 81, "Social" :85 },

'Grade' :  "PASS" ,

'Address' : "Hyderabad" ,

'Contact_info' : { 'Phone Number' : 8945612370, 'Mail-id' : " arcch@gmail.com" }

}
}

import pprint

pprint.pp(std_1)
pprint.pp(std_2)
pprint.pp(std_3)
# Out:
# {'Sneha': {'Marks': {'Maths': 98,
#                      'Telugu': 95,
#                      'English': 92,
#                      'Hindi': 95,
#                      'Science': 96,
#                      'Social': 98},
#            'Grade': 'PASS',
#            'Address': 'Hyderabad',
#            'Contact_info': {'Phone Number': 9874561230,
#                             'Mail-id': ' msl@gmail.com'}}}
# {'Ravalika': {'Marks': {'Maths': 96,
#                         'Telugu': 94,
#                         'English': 91,
#                         'Hindi': 90,
#                         'Science': 90,
#                         'Social': 94},
#               'Grade': 'PASS',
#               'Address': 'Hyderabad',
#               'Contact_info': {'Phone Number': 7894561230,
#                                'Mail-id': ' prr@gmail.com'}}}
# {'Archana': {'Marks': {'Maths': 98,
#                        'Telugu': 98,
#                        'English': 96,
# ...
